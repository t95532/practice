# %% [markdown]
# # Mlflow
# ### MLflow is an open-source platform used to manage the end-to-end machine learning lifecycle.
# >Experiment tracking
#
# >model packaging
#
# >model versioning
#
# >model deployment

# %%
import mlflow

# %%
mlflow.active_run()
